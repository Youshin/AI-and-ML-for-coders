# %% [markdown]
# <a href="https://colab.research.google.com/github/Youshin/AI-and-ML-for-coders/blob/main/1%EC%9E%A5_%ED%85%90%EC%84%9C%ED%94%8C%EB%A1%9C_%EC%86%8C%EA%B0%9C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 텐서플로 사용 및 설치

# %%
# !pip install tensorflow
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %% [markdown]
# ## GPU와 드라이버가 준비되어 있지 않을 경우

# %%
# !pip install tensorflow-cpu
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 221.4 MB 54 kB/s
# ...
#      |████████████████████████████████| 1.7 MB 47.3 MB/s
# ...
#      |████████████████████████████████| 6.0 MB 43.0 MB/s
# ...
#      |████████████████████████████████| 439 kB 60.0 MB/s
# ...
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.9.0
#     Uninstalling tensorflow-estimator-2.9.0:
#       Successfully uninstalled tensorflow-estimator-2.9.0
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.9.1
#     Uninstalling tensorboard-2.9.1:
#       Successfully uninstalled tensorboard-2.9.1
#   Attempting uninstall: keras
#     Found existing installation: keras 2.9.0
#     Uninstalling keras-2.9.0:
#       Successfully uninstalled keras-2.9.0
#   Attempting uninstall: flatbuffers
#     Found existing installation: flatbuffers 1.12
# ...

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.11.0

# %% [markdown]
# ## 원하는 버전으로 설치

# %%
# !pip install tensorflow==2.2.0
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 516.3 MB 3.3 kB/s
# ...
#      |████████████████████████████████| 26.0 MB 1.2 MB/s
# ...
#      |████████████████████████████████| 3.0 MB 40.1 MB/s
# ...
#      |████████████████████████████████| 454 kB 27.9 MB/s
# ...
#      |████████████████████████████████| 2.9 MB 31.1 MB/s
# ...
#      |████████████████████████████████| 152 kB 76.1 MB/s
# ...
#   Attempting uninstall: cachetools
#     Found existing installation: cachetools 5.2.0
#     Uninstalling cachetools-5.2.0:
#       Successfully uninstalled cachetools-5.2.0
#   Attempting uninstall: google-auth
#     Found existing installation: google-auth 2.15.0
#     Uninstalling google-auth-2.15.0:
#       Successfully uninstalled google-auth-2.15.0
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.11.0
#     Uninstalling tensorflow-estimator-2.11.0:
# ...

# %%
"""
x 값과 y 값은 관련이 있습니다.
조금만 생각해보면, Y = 2X - 1라는 패턴을 발견할 수 있습니다.
"""
x = -1, 0, 1, 2, 3, 4
y = -3, -1, 1, 3, 5, 7

# %%
import tensorflow as tf
import numpy as np
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense

# Sequential 클래스로 층을 정의합니다. (Sequential 클래스 안에 한 줄의 코드만 있으므로 하나의 층만 가집니다.)
# keras.layers API를 사용해 층을 정의합니다. 여기서는 Dense 층을 사용합니다. (뉴런이 완전히 연결되어 있다는 것을 의미합니다. p.41 [그림 1-18])
# Dense 층을 units=1로 설정했기 때문에 이 층은 1개의 뉴런을 가집니다.
dense = Dense(units=1, input_shape=[1])
model = Sequential([dense]) 

# 상황에 맞는 옵티마이저를 고르기만 하면 됩니다.
# sgd = 확률적 경사 하강법stochastic gradient descent의 약자.
model.compile(optimizer='sgd', loss='mean_squared_error')

xs = np.array(x, dtype=float)
ys = np.array(y, dtype=float)

model.fit(xs, ys, epochs=500)

print(model.predict([10.0]))
# Out:
# Epoch 1/500
# 1/1 [==============================] - 0s 272ms/step - loss: 18.7228
# Epoch 2/500
# 1/1 [==============================] - 0s 10ms/step - loss: 14.9900
# Epoch 3/500
# 1/1 [==============================] - 0s 9ms/step - loss: 12.0480
# Epoch 4/500
# 1/1 [==============================] - 0s 9ms/step - loss: 9.7281
# Epoch 5/500
# 1/1 [==============================] - 0s 8ms/step - loss: 7.8978
# Epoch 6/500
# 1/1 [==============================] - 0s 15ms/step - loss: 6.4527
# Epoch 7/500
# 1/1 [==============================] - 0s 10ms/step - loss: 5.3110
# Epoch 8/500
# 1/1 [==============================] - 0s 10ms/step - loss: 4.4078
# Epoch 9/500
# 1/1 [==============================] - 0s 17ms/step - loss: 3.6926
# Epoch 10/500
# 1/1 [==============================] - 0s 9ms/step - loss: 3.1253
# Epoch 11/500
# 1/1 [==============================] - 0s 9ms/step - loss: 2.6744
# Epoch 12/500
# 1/1 [==============================] - 0s 9ms/step - loss: 2.3153
# ...

# %%
# Y = {첫번째 배열의 값}X - {두번째 배열의 값} ex Y = 1.9972315X - 0.991417
print(f"신경망이 학습한 것: {dense.get_weights()}")
# Out:
# 신경망이 학습한 것: [array([[1.9972315]], dtype=float32), array([-0.991417], dtype=float32)]
